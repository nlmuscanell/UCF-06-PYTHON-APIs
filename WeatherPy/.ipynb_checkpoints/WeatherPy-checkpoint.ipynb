# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
from scipy.stats import linregress
from scipy import stats
import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set up lists to hold response info
name = []
clouds = []
country = []
date = []
humidity = []
lat = []
lon = []
temp = []
wind = []

# Url components
url = "http://api.openweathermap.org/data/2.5/weather?q="
api_key = "&appid=" + weather_api_key
units = "&units=imperial"

# %%
# Set up a counter for the print log
record = 0

# loop through cities, make requests and parse
for city in cities:
    try:
        target_url = (url + city + api_key + units)
        response = requests.get(target_url).json()
        name.append(response['name'])
        clouds.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        # Add to counter
        record += 1   
        print(f"Retrieved data for {city}.")
        print(target_url)
    # Exceptions for a city that is not found
    except:
        print(f"No data found for {city}.")      
    # Set the time sleep to kick in right before it gets to the call limit (60)
    if record % 59 == 0:
        time.sleep(2)
        
print("------------------")
print("Printing Complete.")
# Out:
# No data found for marcona.
# Retrieved data for upernavik.
# http://api.openweathermap.org/data/2.5/weather?q=upernavik&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for taolanaro.
# Retrieved data for hami.
# http://api.openweathermap.org/data/2.5/weather?q=hami&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for jamestown.
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for kanniyakumari.
# http://api.openweathermap.org/data/2.5/weather?q=kanniyakumari&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for coahuayana.
# http://api.openweathermap.org/data/2.5/weather?q=coahuayana&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for golden.
# http://api.openweathermap.org/data/2.5/weather?q=golden&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for saint george.
# http://api.openweathermap.org/data/2.5/weather?q=saint george&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for cape town.
# http://api.openweathermap.org/data/2.5/weather?q=cape town&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for marsa matruh.
# http://api.openweathermap.org/data/2.5/weather?q=marsa matruh&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for carnarvon.
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ada.
# http://api.openweathermap.org/data/2.5/weather?q=ada&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for cayenne.
# http://api.openweathermap.org/data/2.5/weather?q=cayenne&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for port antonio.
# http://api.openweathermap.org/data/2.5/weather?q=port antonio&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for kaitangata.
# http://api.openweathermap.org/data/2.5/weather?q=kaitangata&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for punta arenas.
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ushuaia.
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for hermanus.
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for belsand.
# http://api.openweathermap.org/data/2.5/weather?q=belsand&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for kedrovyy.
# http://api.openweathermap.org/data/2.5/weather?q=kedrovyy&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for hilo.
# http://api.openweathermap.org/data/2.5/weather?q=hilo&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ribeira grande.
# http://api.openweathermap.org/data/2.5/weather?q=ribeira grande&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ilulissat.
# http://api.openweathermap.org/data/2.5/weather?q=ilulissat&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for puerto ayora.
# http://api.openweathermap.org/data/2.5/weather?q=puerto ayora&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for segou.
# http://api.openweathermap.org/data/2.5/weather?q=segou&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for salalah.
# http://api.openweathermap.org/data/2.5/weather?q=salalah&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for nalut.
# http://api.openweathermap.org/data/2.5/weather?q=nalut&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for beringovskiy.
# http://api.openweathermap.org/data/2.5/weather?q=beringovskiy&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for arraial do cabo.
# http://api.openweathermap.org/data/2.5/weather?q=arraial do cabo&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for san patricio.
# http://api.openweathermap.org/data/2.5/weather?q=san patricio&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for illoqqortoormiut.
# Retrieved data for ngawen.
# http://api.openweathermap.org/data/2.5/weather?q=ngawen&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for manta.
# http://api.openweathermap.org/data/2.5/weather?q=manta&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for bubaque.
# http://api.openweathermap.org/data/2.5/weather?q=bubaque&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for norman wells.
# http://api.openweathermap.org/data/2.5/weather?q=norman wells&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for kapaa.
# http://api.openweathermap.org/data/2.5/weather?q=kapaa&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for itoman.
# http://api.openweathermap.org/data/2.5/weather?q=itoman&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for fomboni.
# http://api.openweathermap.org/data/2.5/weather?q=fomboni&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for halalo.
# Retrieved data for broken hill.
# http://api.openweathermap.org/data/2.5/weather?q=broken hill&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for albany.
# http://api.openweathermap.org/data/2.5/weather?q=albany&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for hasaki.
# http://api.openweathermap.org/data/2.5/weather?q=hasaki&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for bambous virieux.
# http://api.openweathermap.org/data/2.5/weather?q=bambous virieux&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for bonavista.
# http://api.openweathermap.org/data/2.5/weather?q=bonavista&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for odweyne.
# http://api.openweathermap.org/data/2.5/weather?q=odweyne&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for rikitea.
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for kodiak.
# http://api.openweathermap.org/data/2.5/weather?q=kodiak&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for bluff.
# http://api.openweathermap.org/data/2.5/weather?q=bluff&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for busselton.
# http://api.openweathermap.org/data/2.5/weather?q=busselton&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for bredasdorp.
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for lasa.
# http://api.openweathermap.org/data/2.5/weather?q=lasa&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for shupiyan.
# http://api.openweathermap.org/data/2.5/weather?q=shupiyan&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for sheregesh.
# http://api.openweathermap.org/data/2.5/weather?q=sheregesh&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for mataura.
# http://api.openweathermap.org/data/2.5/weather?q=mataura&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for kavieng.
# http://api.openweathermap.org/data/2.5/weather?q=kavieng&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for nikolskoye.
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for dikson.
# http://api.openweathermap.org/data/2.5/weather?q=dikson&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ahipara.
# http://api.openweathermap.org/data/2.5/weather?q=ahipara&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for hithadhoo.
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for johi.
# http://api.openweathermap.org/data/2.5/weather?q=johi&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for okhotsk.
# http://api.openweathermap.org/data/2.5/weather?q=okhotsk&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for mount gambier.
# http://api.openweathermap.org/data/2.5/weather?q=mount gambier&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for provideniya.
# http://api.openweathermap.org/data/2.5/weather?q=provideniya&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for teguldet.
# http://api.openweathermap.org/data/2.5/weather?q=teguldet&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for chail.
# http://api.openweathermap.org/data/2.5/weather?q=chail&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for rio grande.
# http://api.openweathermap.org/data/2.5/weather?q=rio grande&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for indramayu.
# http://api.openweathermap.org/data/2.5/weather?q=indramayu&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for nanakuli.
# http://api.openweathermap.org/data/2.5/weather?q=nanakuli&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for atuona.
# http://api.openweathermap.org/data/2.5/weather?q=atuona&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for lebu.
# http://api.openweathermap.org/data/2.5/weather?q=lebu&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for khatanga.
# http://api.openweathermap.org/data/2.5/weather?q=khatanga&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for qaqortoq.
# http://api.openweathermap.org/data/2.5/weather?q=qaqortoq&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for yuncheng.
# http://api.openweathermap.org/data/2.5/weather?q=yuncheng&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for xinglongshan.
# http://api.openweathermap.org/data/2.5/weather?q=xinglongshan&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for shanghai.
# http://api.openweathermap.org/data/2.5/weather?q=shanghai&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for oktyabrskiy.
# http://api.openweathermap.org/data/2.5/weather?q=oktyabrskiy&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for sentyabrskiy.
# Retrieved data for lagoa.
# http://api.openweathermap.org/data/2.5/weather?q=lagoa&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for tuktoyaktuk.
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for cabo san lucas.
# http://api.openweathermap.org/data/2.5/weather?q=cabo san lucas&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for airai.
# http://api.openweathermap.org/data/2.5/weather?q=airai&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for quelimane.
# http://api.openweathermap.org/data/2.5/weather?q=quelimane&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for amderma.
# Retrieved data for ixtapa.
# http://api.openweathermap.org/data/2.5/weather?q=ixtapa&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for semirara.
# http://api.openweathermap.org/data/2.5/weather?q=semirara&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for the valley.
# http://api.openweathermap.org/data/2.5/weather?q=the valley&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for thompson.
# http://api.openweathermap.org/data/2.5/weather?q=thompson&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for port alfred.
# http://api.openweathermap.org/data/2.5/weather?q=port alfred&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for acapulco.
# http://api.openweathermap.org/data/2.5/weather?q=acapulco&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for wanning.
# http://api.openweathermap.org/data/2.5/weather?q=wanning&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for meulaboh.
# http://api.openweathermap.org/data/2.5/weather?q=meulaboh&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for caravelas.
# http://api.openweathermap.org/data/2.5/weather?q=caravelas&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for samusu.
# Retrieved data for nhulunbuy.
# http://api.openweathermap.org/data/2.5/weather?q=nhulunbuy&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for west bay.
# http://api.openweathermap.org/data/2.5/weather?q=west bay&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for lavrentiya.
# http://api.openweathermap.org/data/2.5/weather?q=lavrentiya&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for katherine.
# http://api.openweathermap.org/data/2.5/weather?q=katherine&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for mar del plata.
# http://api.openweathermap.org/data/2.5/weather?q=mar del plata&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for adrar.
# http://api.openweathermap.org/data/2.5/weather?q=adrar&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for barrow.
# http://api.openweathermap.org/data/2.5/weather?q=barrow&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for roald.
# http://api.openweathermap.org/data/2.5/weather?q=roald&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for surazh.
# http://api.openweathermap.org/data/2.5/weather?q=surazh&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for saskylakh.
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for areka.
# http://api.openweathermap.org/data/2.5/weather?q=areka&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for east london.
# http://api.openweathermap.org/data/2.5/weather?q=east london&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for faanui.
# http://api.openweathermap.org/data/2.5/weather?q=faanui&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for clevedon.
# http://api.openweathermap.org/data/2.5/weather?q=clevedon&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for maan.
# http://api.openweathermap.org/data/2.5/weather?q=maan&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for katsuura.
# http://api.openweathermap.org/data/2.5/weather?q=katsuura&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for kuusamo.
# http://api.openweathermap.org/data/2.5/weather?q=kuusamo&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for troitsko-pechorsk.
# http://api.openweathermap.org/data/2.5/weather?q=troitsko-pechorsk&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for dawei.
# http://api.openweathermap.org/data/2.5/weather?q=dawei&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for yellowknife.
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for raisinghnagar.
# http://api.openweathermap.org/data/2.5/weather?q=raisinghnagar&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for razole.
# http://api.openweathermap.org/data/2.5/weather?q=razole&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for eyl.
# http://api.openweathermap.org/data/2.5/weather?q=eyl&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for new norfolk.
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for rayadrug.
# http://api.openweathermap.org/data/2.5/weather?q=rayadrug&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for oranjemund.
# http://api.openweathermap.org/data/2.5/weather?q=oranjemund&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for zlatoustovsk.
# Retrieved data for bandarbeyla.
# http://api.openweathermap.org/data/2.5/weather?q=bandarbeyla&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for attawapiskat.
# No data found for vaitupu.
# Retrieved data for taltal.
# http://api.openweathermap.org/data/2.5/weather?q=taltal&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for saint-joseph.
# http://api.openweathermap.org/data/2.5/weather?q=saint-joseph&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for bom jesus.
# http://api.openweathermap.org/data/2.5/weather?q=bom jesus&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for madrid.
# http://api.openweathermap.org/data/2.5/weather?q=madrid&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for dwarka.
# http://api.openweathermap.org/data/2.5/weather?q=dwarka&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for hambantota.
# http://api.openweathermap.org/data/2.5/weather?q=hambantota&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for shimoda.
# http://api.openweathermap.org/data/2.5/weather?q=shimoda&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for cabedelo.
# http://api.openweathermap.org/data/2.5/weather?q=cabedelo&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for mnogovershinnyy.
# http://api.openweathermap.org/data/2.5/weather?q=mnogovershinnyy&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for qaanaaq.
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for karakose.
# Retrieved data for kavaratti.
# http://api.openweathermap.org/data/2.5/weather?q=kavaratti&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for barcelos.
# http://api.openweathermap.org/data/2.5/weather?q=barcelos&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for nizhneyansk.
# Retrieved data for avarua.
# http://api.openweathermap.org/data/2.5/weather?q=avarua&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for souillac.
# http://api.openweathermap.org/data/2.5/weather?q=souillac&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for aljezur.
# http://api.openweathermap.org/data/2.5/weather?q=aljezur&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for romny.
# http://api.openweathermap.org/data/2.5/weather?q=romny&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for hobart.
# http://api.openweathermap.org/data/2.5/weather?q=hobart&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for tual.
# http://api.openweathermap.org/data/2.5/weather?q=tual&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for koumac.
# http://api.openweathermap.org/data/2.5/weather?q=koumac&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for zeya.
# http://api.openweathermap.org/data/2.5/weather?q=zeya&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for luderitz.
# http://api.openweathermap.org/data/2.5/weather?q=luderitz&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for scottsburgh.
# Retrieved data for whitehorse.
# http://api.openweathermap.org/data/2.5/weather?q=whitehorse&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for bocas del toro.
# http://api.openweathermap.org/data/2.5/weather?q=bocas del toro&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for sura.
# http://api.openweathermap.org/data/2.5/weather?q=sura&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for yanchukan.
# Retrieved data for spring valley.
# http://api.openweathermap.org/data/2.5/weather?q=spring valley&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for iqaluit.
# http://api.openweathermap.org/data/2.5/weather?q=iqaluit&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for narrabri.
# http://api.openweathermap.org/data/2.5/weather?q=narrabri&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for vaitape.
# http://api.openweathermap.org/data/2.5/weather?q=vaitape&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for vila velha.
# http://api.openweathermap.org/data/2.5/weather?q=vila velha&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for tando muhammad khan.
# http://api.openweathermap.org/data/2.5/weather?q=tando muhammad khan&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for longyearbyen.
# http://api.openweathermap.org/data/2.5/weather?q=longyearbyen&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for tasiilaq.
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for castro.
# http://api.openweathermap.org/data/2.5/weather?q=castro&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for hokitika.
# http://api.openweathermap.org/data/2.5/weather?q=hokitika&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for abha.
# http://api.openweathermap.org/data/2.5/weather?q=abha&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for warragul.
# http://api.openweathermap.org/data/2.5/weather?q=warragul&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for xichang.
# http://api.openweathermap.org/data/2.5/weather?q=xichang&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for quartucciu.
# http://api.openweathermap.org/data/2.5/weather?q=quartucciu&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for brae.
# http://api.openweathermap.org/data/2.5/weather?q=brae&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for baykit.
# http://api.openweathermap.org/data/2.5/weather?q=baykit&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for banda aceh.
# http://api.openweathermap.org/data/2.5/weather?q=banda aceh&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for matara.
# http://api.openweathermap.org/data/2.5/weather?q=matara&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for egvekinot.
# http://api.openweathermap.org/data/2.5/weather?q=egvekinot&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for kirakira.
# http://api.openweathermap.org/data/2.5/weather?q=kirakira&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for belushya guba.
# No data found for phan rang.
# Retrieved data for vaini.
# http://api.openweathermap.org/data/2.5/weather?q=vaini&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for liverpool.
# http://api.openweathermap.org/data/2.5/weather?q=liverpool&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for boden.
# http://api.openweathermap.org/data/2.5/weather?q=boden&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for vila franca do campo.
# http://api.openweathermap.org/data/2.5/weather?q=vila franca do campo&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for lata.
# http://api.openweathermap.org/data/2.5/weather?q=lata&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for rocha.
# http://api.openweathermap.org/data/2.5/weather?q=rocha&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for gulu.
# http://api.openweathermap.org/data/2.5/weather?q=gulu&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for butaritari.
# http://api.openweathermap.org/data/2.5/weather?q=butaritari&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for havoysund.
# http://api.openweathermap.org/data/2.5/weather?q=havoysund&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for bengkulu.
# http://api.openweathermap.org/data/2.5/weather?q=bengkulu&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for anadyr.
# http://api.openweathermap.org/data/2.5/weather?q=anadyr&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for fairbanks.
# http://api.openweathermap.org/data/2.5/weather?q=fairbanks&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ellisras.
# http://api.openweathermap.org/data/2.5/weather?q=ellisras&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for sioux lookout.
# http://api.openweathermap.org/data/2.5/weather?q=sioux lookout&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for guerrero negro.
# http://api.openweathermap.org/data/2.5/weather?q=guerrero negro&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for husavik.
# http://api.openweathermap.org/data/2.5/weather?q=husavik&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for shache.
# http://api.openweathermap.org/data/2.5/weather?q=shache&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for kruisfontein.
# http://api.openweathermap.org/data/2.5/weather?q=kruisfontein&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for sao sebastiao.
# http://api.openweathermap.org/data/2.5/weather?q=sao sebastiao&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for mbekenyera.
# http://api.openweathermap.org/data/2.5/weather?q=mbekenyera&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for emerald.
# http://api.openweathermap.org/data/2.5/weather?q=emerald&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ekhabi.
# http://api.openweathermap.org/data/2.5/weather?q=ekhabi&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for chapais.
# http://api.openweathermap.org/data/2.5/weather?q=chapais&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for jumla.
# http://api.openweathermap.org/data/2.5/weather?q=jumla&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for honningsvag.
# http://api.openweathermap.org/data/2.5/weather?q=honningsvag&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for uttarkashi.
# http://api.openweathermap.org/data/2.5/weather?q=uttarkashi&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for champerico.
# http://api.openweathermap.org/data/2.5/weather?q=champerico&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for saldanha.
# http://api.openweathermap.org/data/2.5/weather?q=saldanha&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for victoria.
# http://api.openweathermap.org/data/2.5/weather?q=victoria&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for belaya gora.
# http://api.openweathermap.org/data/2.5/weather?q=belaya gora&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for pavilosta.
# http://api.openweathermap.org/data/2.5/weather?q=pavilosta&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for roma.
# http://api.openweathermap.org/data/2.5/weather?q=roma&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for tautira.
# http://api.openweathermap.org/data/2.5/weather?q=tautira&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for nuuk.
# http://api.openweathermap.org/data/2.5/weather?q=nuuk&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for tazovskiy.
# http://api.openweathermap.org/data/2.5/weather?q=tazovskiy&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for hovd.
# http://api.openweathermap.org/data/2.5/weather?q=hovd&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for asau.
# http://api.openweathermap.org/data/2.5/weather?q=asau&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for kontagora.
# http://api.openweathermap.org/data/2.5/weather?q=kontagora&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for saleaula.
# No data found for galiwinku.
# Retrieved data for gazanjyk.
# http://api.openweathermap.org/data/2.5/weather?q=gazanjyk&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for baboua.
# Retrieved data for presidencia roque saenz pena.
# http://api.openweathermap.org/data/2.5/weather?q=presidencia roque saenz pena&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for lompoc.
# http://api.openweathermap.org/data/2.5/weather?q=lompoc&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for tiksi.
# http://api.openweathermap.org/data/2.5/weather?q=tiksi&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for jiujiang.
# http://api.openweathermap.org/data/2.5/weather?q=jiujiang&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for inongo.
# http://api.openweathermap.org/data/2.5/weather?q=inongo&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for wukari.
# http://api.openweathermap.org/data/2.5/weather?q=wukari&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for cedar city.
# http://api.openweathermap.org/data/2.5/weather?q=cedar city&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for chabahar.
# http://api.openweathermap.org/data/2.5/weather?q=chabahar&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for kloulklubed.
# http://api.openweathermap.org/data/2.5/weather?q=kloulklubed&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for new haven.
# http://api.openweathermap.org/data/2.5/weather?q=new haven&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ust-nera.
# http://api.openweathermap.org/data/2.5/weather?q=ust-nera&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for san cristobal.
# http://api.openweathermap.org/data/2.5/weather?q=san cristobal&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for mahajanga.
# http://api.openweathermap.org/data/2.5/weather?q=mahajanga&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for paradwip.
# Retrieved data for bilma.
# http://api.openweathermap.org/data/2.5/weather?q=bilma&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for lonar.
# http://api.openweathermap.org/data/2.5/weather?q=lonar&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for nueva gorgona.
# http://api.openweathermap.org/data/2.5/weather?q=nueva gorgona&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for richards bay.
# http://api.openweathermap.org/data/2.5/weather?q=richards bay&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for port shepstone.
# http://api.openweathermap.org/data/2.5/weather?q=port shepstone&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for artyk.
# Retrieved data for chulman.
# http://api.openweathermap.org/data/2.5/weather?q=chulman&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for labuhan.
# http://api.openweathermap.org/data/2.5/weather?q=labuhan&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for opuwo.
# http://api.openweathermap.org/data/2.5/weather?q=opuwo&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ambanja.
# http://api.openweathermap.org/data/2.5/weather?q=ambanja&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for new agutaya.
# http://api.openweathermap.org/data/2.5/weather?q=new agutaya&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for namatanai.
# http://api.openweathermap.org/data/2.5/weather?q=namatanai&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for fernley.
# http://api.openweathermap.org/data/2.5/weather?q=fernley&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for coihaique.
# http://api.openweathermap.org/data/2.5/weather?q=coihaique&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for port elizabeth.
# http://api.openweathermap.org/data/2.5/weather?q=port elizabeth&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for klaksvik.
# http://api.openweathermap.org/data/2.5/weather?q=klaksvik&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for barentsburg.
# Retrieved data for okahandja.
# http://api.openweathermap.org/data/2.5/weather?q=okahandja&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for samarai.
# http://api.openweathermap.org/data/2.5/weather?q=samarai&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for bowen.
# http://api.openweathermap.org/data/2.5/weather?q=bowen&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for kazachinskoye.
# http://api.openweathermap.org/data/2.5/weather?q=kazachinskoye&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for georgetown.
# http://api.openweathermap.org/data/2.5/weather?q=georgetown&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for plettenberg bay.
# http://api.openweathermap.org/data/2.5/weather?q=plettenberg bay&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for choya.
# http://api.openweathermap.org/data/2.5/weather?q=choya&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for marsh harbour.
# http://api.openweathermap.org/data/2.5/weather?q=marsh harbour&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for xining.
# http://api.openweathermap.org/data/2.5/weather?q=xining&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for miri.
# http://api.openweathermap.org/data/2.5/weather?q=miri&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for tsihombe.
# Retrieved data for christchurch.
# http://api.openweathermap.org/data/2.5/weather?q=christchurch&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ishigaki.
# http://api.openweathermap.org/data/2.5/weather?q=ishigaki&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for nabire.
# http://api.openweathermap.org/data/2.5/weather?q=nabire&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for gondanglegi.
# http://api.openweathermap.org/data/2.5/weather?q=gondanglegi&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ikalamavony.
# http://api.openweathermap.org/data/2.5/weather?q=ikalamavony&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for nizwa.
# http://api.openweathermap.org/data/2.5/weather?q=nizwa&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for dori.
# http://api.openweathermap.org/data/2.5/weather?q=dori&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for quatre cocos.
# http://api.openweathermap.org/data/2.5/weather?q=quatre cocos&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for palmer.
# http://api.openweathermap.org/data/2.5/weather?q=palmer&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for bembereke.
# http://api.openweathermap.org/data/2.5/weather?q=bembereke&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for port hedland.
# http://api.openweathermap.org/data/2.5/weather?q=port hedland&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for axim.
# http://api.openweathermap.org/data/2.5/weather?q=axim&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for cidreira.
# http://api.openweathermap.org/data/2.5/weather?q=cidreira&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for wairoa.
# http://api.openweathermap.org/data/2.5/weather?q=wairoa&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for zhangye.
# http://api.openweathermap.org/data/2.5/weather?q=zhangye&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for okha.
# http://api.openweathermap.org/data/2.5/weather?q=okha&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for esperance.
# http://api.openweathermap.org/data/2.5/weather?q=esperance&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for sao filipe.
# http://api.openweathermap.org/data/2.5/weather?q=sao filipe&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for luanda.
# http://api.openweathermap.org/data/2.5/weather?q=luanda&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for chingola.
# http://api.openweathermap.org/data/2.5/weather?q=chingola&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for vnukovo.
# http://api.openweathermap.org/data/2.5/weather?q=vnukovo&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for svetlogorsk.
# http://api.openweathermap.org/data/2.5/weather?q=svetlogorsk&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for isangel.
# http://api.openweathermap.org/data/2.5/weather?q=isangel&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for cairns.
# http://api.openweathermap.org/data/2.5/weather?q=cairns&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for samalaeulu.
# Retrieved data for hofn.
# http://api.openweathermap.org/data/2.5/weather?q=hofn&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for gimbi.
# http://api.openweathermap.org/data/2.5/weather?q=gimbi&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for mana.
# http://api.openweathermap.org/data/2.5/weather?q=mana&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for saint-pierre.
# http://api.openweathermap.org/data/2.5/weather?q=saint-pierre&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for sept-iles.
# http://api.openweathermap.org/data/2.5/weather?q=sept-iles&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for odoyev.
# http://api.openweathermap.org/data/2.5/weather?q=odoyev&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for petropavlovsk-kamchatskiy.
# http://api.openweathermap.org/data/2.5/weather?q=petropavlovsk-kamchatskiy&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for almaznyy.
# http://api.openweathermap.org/data/2.5/weather?q=almaznyy&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for bethel.
# http://api.openweathermap.org/data/2.5/weather?q=bethel&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for balykshi.
# http://api.openweathermap.org/data/2.5/weather?q=balykshi&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for poya.
# http://api.openweathermap.org/data/2.5/weather?q=poya&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for yalutorovsk.
# http://api.openweathermap.org/data/2.5/weather?q=yalutorovsk&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for clyde river.
# http://api.openweathermap.org/data/2.5/weather?q=clyde river&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for port lincoln.
# http://api.openweathermap.org/data/2.5/weather?q=port lincoln&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for omsukchan.
# http://api.openweathermap.org/data/2.5/weather?q=omsukchan&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for sovetskoye.
# http://api.openweathermap.org/data/2.5/weather?q=sovetskoye&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for port hardy.
# http://api.openweathermap.org/data/2.5/weather?q=port hardy&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for baunatal.
# http://api.openweathermap.org/data/2.5/weather?q=baunatal&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ballina.
# http://api.openweathermap.org/data/2.5/weather?q=ballina&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for varhaug.
# http://api.openweathermap.org/data/2.5/weather?q=varhaug&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for prince rupert.
# http://api.openweathermap.org/data/2.5/weather?q=prince rupert&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for chokurdakh.
# http://api.openweathermap.org/data/2.5/weather?q=chokurdakh&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for grand river south east.
# Retrieved data for chuy.
# http://api.openweathermap.org/data/2.5/weather?q=chuy&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for yirol.
# Retrieved data for gamba.
# http://api.openweathermap.org/data/2.5/weather?q=gamba&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for planadas.
# http://api.openweathermap.org/data/2.5/weather?q=planadas&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for timmins.
# http://api.openweathermap.org/data/2.5/weather?q=timmins&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for kajaani.
# http://api.openweathermap.org/data/2.5/weather?q=kajaani&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for clovis.
# http://api.openweathermap.org/data/2.5/weather?q=clovis&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for mys shmidta.
# Retrieved data for pevek.
# http://api.openweathermap.org/data/2.5/weather?q=pevek&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for durusu.
# http://api.openweathermap.org/data/2.5/weather?q=durusu&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for arman.
# http://api.openweathermap.org/data/2.5/weather?q=arman&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for pasni.
# http://api.openweathermap.org/data/2.5/weather?q=pasni&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for nanortalik.
# http://api.openweathermap.org/data/2.5/weather?q=nanortalik&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for yaan.
# http://api.openweathermap.org/data/2.5/weather?q=yaan&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for neuquen.
# http://api.openweathermap.org/data/2.5/weather?q=neuquen&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for laguna.
# http://api.openweathermap.org/data/2.5/weather?q=laguna&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for sajanan.
# http://api.openweathermap.org/data/2.5/weather?q=sajanan&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for gravdal.
# http://api.openweathermap.org/data/2.5/weather?q=gravdal&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ketchikan.
# http://api.openweathermap.org/data/2.5/weather?q=ketchikan&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for wakkanai.
# http://api.openweathermap.org/data/2.5/weather?q=wakkanai&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for kyabram.
# http://api.openweathermap.org/data/2.5/weather?q=kyabram&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for mani.
# http://api.openweathermap.org/data/2.5/weather?q=mani&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for saint anthony.
# http://api.openweathermap.org/data/2.5/weather?q=saint anthony&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for karauzyak.
# Retrieved data for whitianga.
# http://api.openweathermap.org/data/2.5/weather?q=whitianga&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for hirara.
# http://api.openweathermap.org/data/2.5/weather?q=hirara&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for labrea.
# http://api.openweathermap.org/data/2.5/weather?q=labrea&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ponta do sol.
# http://api.openweathermap.org/data/2.5/weather?q=ponta do sol&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for olafsvik.
# http://api.openweathermap.org/data/2.5/weather?q=olafsvik&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for isabela.
# http://api.openweathermap.org/data/2.5/weather?q=isabela&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for bytow.
# http://api.openweathermap.org/data/2.5/weather?q=bytow&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for hamburg.
# http://api.openweathermap.org/data/2.5/weather?q=hamburg&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for touros.
# http://api.openweathermap.org/data/2.5/weather?q=touros&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ust-maya.
# http://api.openweathermap.org/data/2.5/weather?q=ust-maya&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for alta floresta.
# http://api.openweathermap.org/data/2.5/weather?q=alta floresta&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for manono.
# http://api.openweathermap.org/data/2.5/weather?q=manono&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for san quintin.
# http://api.openweathermap.org/data/2.5/weather?q=san quintin&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for mwandiga.
# http://api.openweathermap.org/data/2.5/weather?q=mwandiga&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for smidovich.
# http://api.openweathermap.org/data/2.5/weather?q=smidovich&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for sola.
# http://api.openweathermap.org/data/2.5/weather?q=sola&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for pampas.
# http://api.openweathermap.org/data/2.5/weather?q=pampas&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for codrington.
# http://api.openweathermap.org/data/2.5/weather?q=codrington&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for vestmannaeyjar.
# http://api.openweathermap.org/data/2.5/weather?q=vestmannaeyjar&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for halifax.
# http://api.openweathermap.org/data/2.5/weather?q=halifax&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for aklavik.
# http://api.openweathermap.org/data/2.5/weather?q=aklavik&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for maniitsoq.
# http://api.openweathermap.org/data/2.5/weather?q=maniitsoq&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for bathsheba.
# http://api.openweathermap.org/data/2.5/weather?q=bathsheba&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for albertville.
# http://api.openweathermap.org/data/2.5/weather?q=albertville&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for saint-augustin.
# http://api.openweathermap.org/data/2.5/weather?q=saint-augustin&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for mangrol.
# http://api.openweathermap.org/data/2.5/weather?q=mangrol&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for waingapu.
# http://api.openweathermap.org/data/2.5/weather?q=waingapu&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for shizunai.
# http://api.openweathermap.org/data/2.5/weather?q=shizunai&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for umm kaddadah.
# http://api.openweathermap.org/data/2.5/weather?q=umm kaddadah&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for buluang.
# http://api.openweathermap.org/data/2.5/weather?q=buluang&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for carmen.
# http://api.openweathermap.org/data/2.5/weather?q=carmen&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for imperia.
# ...
# Retrieved data for warangal.
# http://api.openweathermap.org/data/2.5/weather?q=warangal&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for swan hill.
# http://api.openweathermap.org/data/2.5/weather?q=swan hill&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for parry sound.
# http://api.openweathermap.org/data/2.5/weather?q=parry sound&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ratnagiri.
# http://api.openweathermap.org/data/2.5/weather?q=ratnagiri&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for santa rosalia.
# http://api.openweathermap.org/data/2.5/weather?q=santa rosalia&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for gurgan.
# Retrieved data for dauphin.
# http://api.openweathermap.org/data/2.5/weather?q=dauphin&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for askino.
# http://api.openweathermap.org/data/2.5/weather?q=askino&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ambulu.
# http://api.openweathermap.org/data/2.5/weather?q=ambulu&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for coquimbo.
# http://api.openweathermap.org/data/2.5/weather?q=coquimbo&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for cockburn town.
# http://api.openweathermap.org/data/2.5/weather?q=cockburn town&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for sterling.
# http://api.openweathermap.org/data/2.5/weather?q=sterling&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for porto torres.
# http://api.openweathermap.org/data/2.5/weather?q=porto torres&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for kamenka.
# http://api.openweathermap.org/data/2.5/weather?q=kamenka&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for port hope.
# http://api.openweathermap.org/data/2.5/weather?q=port hope&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for satellite beach.
# http://api.openweathermap.org/data/2.5/weather?q=satellite beach&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for namibe.
# http://api.openweathermap.org/data/2.5/weather?q=namibe&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for vila.
# http://api.openweathermap.org/data/2.5/weather?q=vila&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for pangnirtung.
# http://api.openweathermap.org/data/2.5/weather?q=pangnirtung&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for nioro.
# http://api.openweathermap.org/data/2.5/weather?q=nioro&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for chakia.
# http://api.openweathermap.org/data/2.5/weather?q=chakia&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for aldan.
# http://api.openweathermap.org/data/2.5/weather?q=aldan&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ust-kulom.
# http://api.openweathermap.org/data/2.5/weather?q=ust-kulom&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for matameye.
# Retrieved data for kahului.
# http://api.openweathermap.org/data/2.5/weather?q=kahului&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for sechura.
# http://api.openweathermap.org/data/2.5/weather?q=sechura&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ilhabela.
# http://api.openweathermap.org/data/2.5/weather?q=ilhabela&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for kaeo.
# http://api.openweathermap.org/data/2.5/weather?q=kaeo&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for araguatins.
# Retrieved data for turgenevo.
# http://api.openweathermap.org/data/2.5/weather?q=turgenevo&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for santa catalina.
# http://api.openweathermap.org/data/2.5/weather?q=santa catalina&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for gusau.
# http://api.openweathermap.org/data/2.5/weather?q=gusau&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for kulhudhuffushi.
# http://api.openweathermap.org/data/2.5/weather?q=kulhudhuffushi&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for oparino.
# http://api.openweathermap.org/data/2.5/weather?q=oparino&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for yushala.
# http://api.openweathermap.org/data/2.5/weather?q=yushala&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for edgewater.
# http://api.openweathermap.org/data/2.5/weather?q=edgewater&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for truro.
# http://api.openweathermap.org/data/2.5/weather?q=truro&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ann arbor.
# http://api.openweathermap.org/data/2.5/weather?q=ann arbor&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for praia da vitoria.
# http://api.openweathermap.org/data/2.5/weather?q=praia da vitoria&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for goose creek.
# http://api.openweathermap.org/data/2.5/weather?q=goose creek&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for rudnaya pristan.
# http://api.openweathermap.org/data/2.5/weather?q=rudnaya pristan&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for powassan.
# http://api.openweathermap.org/data/2.5/weather?q=powassan&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for rawannawi.
# Retrieved data for floro.
# http://api.openweathermap.org/data/2.5/weather?q=floro&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for khorixas.
# http://api.openweathermap.org/data/2.5/weather?q=khorixas&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for vilhena.
# http://api.openweathermap.org/data/2.5/weather?q=vilhena&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for guajara-mirim.
# Retrieved data for yar-sale.
# http://api.openweathermap.org/data/2.5/weather?q=yar-sale&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for muisne.
# http://api.openweathermap.org/data/2.5/weather?q=muisne&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for saravan.
# http://api.openweathermap.org/data/2.5/weather?q=saravan&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for guiratinga.
# http://api.openweathermap.org/data/2.5/weather?q=guiratinga&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for sirsa.
# http://api.openweathermap.org/data/2.5/weather?q=sirsa&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for bengkalis.
# Retrieved data for innisfail.
# http://api.openweathermap.org/data/2.5/weather?q=innisfail&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for beloha.
# http://api.openweathermap.org/data/2.5/weather?q=beloha&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for port pirie.
# http://api.openweathermap.org/data/2.5/weather?q=port pirie&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for albemarle.
# http://api.openweathermap.org/data/2.5/weather?q=albemarle&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for bafq.
# http://api.openweathermap.org/data/2.5/weather?q=bafq&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for komsomolskiy.
# http://api.openweathermap.org/data/2.5/weather?q=komsomolskiy&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for sotnikovo.
# http://api.openweathermap.org/data/2.5/weather?q=sotnikovo&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for tello.
# http://api.openweathermap.org/data/2.5/weather?q=tello&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for sotouboua.
# http://api.openweathermap.org/data/2.5/weather?q=sotouboua&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for sibolga.
# http://api.openweathermap.org/data/2.5/weather?q=sibolga&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for cranbrook.
# http://api.openweathermap.org/data/2.5/weather?q=cranbrook&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for akil.
# http://api.openweathermap.org/data/2.5/weather?q=akil&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for paita.
# http://api.openweathermap.org/data/2.5/weather?q=paita&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for corner brook.
# http://api.openweathermap.org/data/2.5/weather?q=corner brook&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for novyy urengoy.
# http://api.openweathermap.org/data/2.5/weather?q=novyy urengoy&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for amga.
# http://api.openweathermap.org/data/2.5/weather?q=amga&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for wembley.
# http://api.openweathermap.org/data/2.5/weather?q=wembley&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for kyra.
# http://api.openweathermap.org/data/2.5/weather?q=kyra&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for raudeberg.
# http://api.openweathermap.org/data/2.5/weather?q=raudeberg&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for verkhnevilyuysk.
# http://api.openweathermap.org/data/2.5/weather?q=verkhnevilyuysk&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for luwuk.
# http://api.openweathermap.org/data/2.5/weather?q=luwuk&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for karamay.
# Retrieved data for torbay.
# http://api.openweathermap.org/data/2.5/weather?q=torbay&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for vardo.
# http://api.openweathermap.org/data/2.5/weather?q=vardo&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for padang.
# http://api.openweathermap.org/data/2.5/weather?q=padang&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for baruun-urt.
# http://api.openweathermap.org/data/2.5/weather?q=baruun-urt&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for san marcos de colon.
# http://api.openweathermap.org/data/2.5/weather?q=san marcos de colon&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for bolama.
# http://api.openweathermap.org/data/2.5/weather?q=bolama&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for araouane.
# http://api.openweathermap.org/data/2.5/weather?q=araouane&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for kijang.
# http://api.openweathermap.org/data/2.5/weather?q=kijang&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for dalby.
# http://api.openweathermap.org/data/2.5/weather?q=dalby&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for wuchang.
# http://api.openweathermap.org/data/2.5/weather?q=wuchang&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ulaangom.
# http://api.openweathermap.org/data/2.5/weather?q=ulaangom&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for launceston.
# http://api.openweathermap.org/data/2.5/weather?q=launceston&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for viedma.
# http://api.openweathermap.org/data/2.5/weather?q=viedma&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for suzu.
# Retrieved data for green river.
# http://api.openweathermap.org/data/2.5/weather?q=green river&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for road town.
# http://api.openweathermap.org/data/2.5/weather?q=road town&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for saint pete beach.
# http://api.openweathermap.org/data/2.5/weather?q=saint pete beach&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for mishan.
# http://api.openweathermap.org/data/2.5/weather?q=mishan&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for betanzos.
# http://api.openweathermap.org/data/2.5/weather?q=betanzos&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for zhitikara.
# Retrieved data for hobyo.
# http://api.openweathermap.org/data/2.5/weather?q=hobyo&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for fuyu.
# http://api.openweathermap.org/data/2.5/weather?q=fuyu&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for moose factory.
# http://api.openweathermap.org/data/2.5/weather?q=moose factory&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for naral.
# Retrieved data for pisco.
# http://api.openweathermap.org/data/2.5/weather?q=pisco&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for dzhusaly.
# Retrieved data for severo-kurilsk.
# http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for arica.
# http://api.openweathermap.org/data/2.5/weather?q=arica&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for caraballeda.
# http://api.openweathermap.org/data/2.5/weather?q=caraballeda&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for aykhal.
# http://api.openweathermap.org/data/2.5/weather?q=aykhal&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for mandalgovi.
# http://api.openweathermap.org/data/2.5/weather?q=mandalgovi&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for disna.
# http://api.openweathermap.org/data/2.5/weather?q=disna&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for mehamn.
# http://api.openweathermap.org/data/2.5/weather?q=mehamn&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for ancud.
# http://api.openweathermap.org/data/2.5/weather?q=ancud&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for comodoro rivadavia.
# http://api.openweathermap.org/data/2.5/weather?q=comodoro rivadavia&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for evensk.
# http://api.openweathermap.org/data/2.5/weather?q=evensk&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for jaguaribe.
# http://api.openweathermap.org/data/2.5/weather?q=jaguaribe&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for srandakan.
# http://api.openweathermap.org/data/2.5/weather?q=srandakan&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for riyadh.
# http://api.openweathermap.org/data/2.5/weather?q=riyadh&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for izvestkovyy.
# http://api.openweathermap.org/data/2.5/weather?q=izvestkovyy&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for loukhi.
# http://api.openweathermap.org/data/2.5/weather?q=loukhi&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for maxixe.
# http://api.openweathermap.org/data/2.5/weather?q=maxixe&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for angangxi.
# Retrieved data for beira.
# http://api.openweathermap.org/data/2.5/weather?q=beira&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for iskitim.
# http://api.openweathermap.org/data/2.5/weather?q=iskitim&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# No data found for moiyabana.
# Retrieved data for kaputa.
# http://api.openweathermap.org/data/2.5/weather?q=kaputa&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# Retrieved data for navahrudak.
# http://api.openweathermap.org/data/2.5/weather?q=navahrudak&appid=73df2cea878643f6b4c2ef4447fe0783&units=imperial
# ------------------
# Printing Complete.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create dataframe for printing and saving file
cities_df = pd.DataFrame({"City Name": name, "Cloudiness": clouds, "Country": country, "Date": date, 
                          "Humidity": humidity, "Latitude" : lat, "Longitude": lon, 
                          "Max Temperature": temp, "Wind Speed": wind})
cities_df.head(10)

# %%
# Save DF as csv file
cities_df.to_csv('cities.csv', header=True, index=True)

# Write file to repository
cities_df = "output_data/cities.csv"

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Re-define DF because above it's defined as output path
cities_df = pd.DataFrame({"City Name": name, "Cloudiness": clouds, "Country": country, "Date": date, 
                          "Humidity": humidity, "Latitude" : lat, "Longitude": lon, 
                          "Max Temperature": temp, "Wind Speed": wind})

# %%
# Get the indices of cities that have humidity over 100% 
cities_df.loc[cities_df["Humidity"]>=101].index

# %% [markdown]
# No values greater than 100 were returned for humidity.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Generating scatterplot
cities_df.plot.scatter(x="Latitude", y="Max Temperature", color='lightcyan', marker='o', s=40, edgecolor='black')

# Font formatting
csfont = {'fontname': "Georgia"}

# Set the title, axis labels, and grid
plt.title("City Latitude by Max Temperature (10.08.20)", fontsize=15, fontweight='bold', **csfont)
plt.xlabel('Latitude', fontsize=14, fontweight='bold', **csfont)
plt.ylabel('Max Temperature (Fahrenheit)', fontsize=14, fontweight='bold', **csfont)
plt.xticks(fontsize=14, **csfont)
plt.yticks(fontsize=14, **csfont)
plt.grid(linestyle='-', linewidth='0.5', color='grey')
plt.savefig("Figures/fig1.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Description
# There appears to be a curvilinear relatinship between city latitude and the maximum temprature. The maximum temperatures decreases as as a geographic location becomes further away from the equator (this is true for both hemispheres). The max temperatures are highest close to the equator.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Generating scatterplot
cities_df.plot.scatter(x="Latitude", y="Humidity", color='lightcyan', marker='o', s=40, edgecolor='black')

# Font formatting
csfont = {'fontname': "Georgia"}

# Set the title, axis labels, and grid
plt.title("City Latitude by Humidity (10.08.20)", fontsize=15, fontweight='bold', **csfont)
plt.xlabel('Latitude', fontsize=14, fontweight='bold', **csfont)
plt.ylabel('Humidity (%)', fontsize=14, fontweight='bold', **csfont)
plt.xticks(fontsize=14, **csfont)
plt.yticks(fontsize=14, **csfont)
plt.grid(linestyle='-', linewidth='0.5', color='grey')
plt.ylim(0, 110)
plt.savefig("Figures/fig2.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Description
# There does not appear to be any linear relationship between city latitude and humidity.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Generating scatterplot
cities_df.plot.scatter(x="Latitude", y="Cloudiness", color='lightcyan', marker='o', s=40, edgecolor='black')

# Font formatting
csfont = {'fontname': "Georgia"}

# Set the title, axis labels, and grid
plt.title("City Latitude by Cloudiness (10.08.20)", fontsize=15, fontweight='bold', **csfont)
plt.xlabel('Latitude', fontsize=14, fontweight='bold', **csfont)
plt.ylabel('Cloudiness (%)', fontsize=14, fontweight='bold', **csfont)
plt.xticks(fontsize=14, **csfont)
plt.yticks(fontsize=14, **csfont)
plt.grid(linestyle='-', linewidth='0.5', color='grey')
plt.ylim(-10, 110)
plt.savefig("Figures/fig3.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Description
# There does not appear to be any significant linear relationship between city latitude and cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Generating scatterplot
cities_df.plot.scatter(x="Latitude", y="Wind Speed", color='lightcyan', marker='o', s=40, edgecolor='black')

# Font formatting
csfont = {'fontname': "Georgia"}

# Set the title, axis labels, and grid
plt.title("City Latitude by Wind Speed (10.08.20)", fontsize=15, fontweight='bold', **csfont)
plt.xlabel('Latitude', fontsize=14, fontweight='bold', **csfont)
plt.ylabel('Wind Speed (mph)', fontsize=14, fontweight='bold', **csfont)
plt.xticks(fontsize=14, **csfont)
plt.yticks(fontsize=14, **csfont)
plt.grid(linestyle='-', linewidth='0.5', color='grey')
plt.ylim(0, 35)
plt.savefig("Figures/fig4.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Description
# There does not appear to be any linear relationship between city latitude and wind speed.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# Run linear regressions on each relationship, only this time separating them into Northern Hemisphere (greater than or equal to 0 degrees latitude) and Southern Hemisphere (less than 0 degrees latitude).

# %%
northern_df = pd.DataFrame(cities_df.loc[cities_df['Latitude']>=0])
northern_df.head()
# Out:
#           City Name  Cloudiness Country        Date  Humidity  Latitude  \
# 0         Upernavik          29      GL  1602171186        89     72.79
# 1             Kumul           0      CN  1602171187        42     42.80
# 2         Jamestown          90      US  1602171187        66     42.10
# 3     Kanniyākumāri          25      IN  1602171187        83      8.08
# 4  Coahuayana Viejo          40      MX  1602171187        73     18.73
#
#    Longitude  Max Temperature  Wind Speed
# 0     -56.15            32.14        9.48
# 1      93.45            47.64        3.53
# 2     -79.24            53.01       14.99
# 3      77.57            80.22       14.83
# 4    -103.68            73.40       11.41

# %%
southern_df = pd.DataFrame(cities_df.loc[cities_df['Latitude']<0])
southern_df.head()
# Out:
#        City Name  Cloudiness Country        Date  Humidity  Latitude  \
# 7      Cape Town          75      ZA  1602171187        55    -33.93
# 9      Carnarvon           0      AU  1602171188        77    -24.87
# 13    Kaitangata           0      NZ  1602171188        64    -46.28
# 14  Punta Arenas          75      CL  1602171078        66    -53.15
# 15       Ushuaia          75      AR  1602171188        65    -54.80
#
#     Longitude  Max Temperature  Wind Speed
# 7       18.42            68.00       10.29
# 9      113.63            66.20       16.11
# 13     169.85            42.01        4.00
# 14     -70.92            48.20       23.04
# 15     -68.30            46.40        3.36

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Set x and y values
x_values = northern_df['Latitude']
y_values = northern_df['Max Temperature']
                                                               
# Linear regression
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker='D', color='fuchsia', s=25, edgecolor='black')
plt.plot(x_values,regress_values,"cyan")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (Fahrenheit)')

# Font formatting
csfont = {'fontname': "Georgia"}

# Set the title and axis labels
plt.title("Max Temp by Latitude (Northern Hem.)", fontsize=15, fontweight='bold', **csfont)
plt.xlabel('Latitude', fontsize=14, fontweight='bold', **csfont)
plt.ylabel('Max Temperature (Fahrenheit))', fontsize=14, fontweight='bold', **csfont)
plt.xticks(fontsize=14, **csfont)
plt.yticks(fontsize=14, **csfont)
plt.show

# Regression coefficient & p-value
print(f"The regression value is {round(rvalue,2)}.")
print(f"The r-squared is: {rvalue**2}.")
print(f"The p-value for this relationship is {round(pvalue,2)}.")
# Out:
# The regression value is -0.85.
# The r-squared is: 0.7155186784965442.
# The p-value for this relationship is 0.0.

# %% [markdown]
# ## Description
# There is a statistically significant negative relationship between latitude and maximum temperature for cities in the nothern hemisphere, p < .001. As geographic location increases further to the north (starting from the equator), temperature decreases. This relationship is strong, as latitude accounts for over 71% of the variance in temperature.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Set x and y values
x_values = southern_df['Latitude']
y_values = southern_df['Max Temperature']
                                                               
# Linear regression
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker='D', color='cyan', s=25, edgecolor='black')
plt.plot(x_values,regress_values,"fuchsia")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (Fahrenheit)')

# Font formatting
csfont = {'fontname': "Georgia"}

# Set the title and axis labels
plt.title("Max Temp by Latitude (Southern Hem.)", fontsize=15, fontweight='bold', **csfont)
plt.xlabel('Latitude', fontsize=14, fontweight='bold', **csfont)
plt.ylabel('Max Temperature (Fahrenheit)', fontsize=14, fontweight='bold', **csfont)
plt.xticks(fontsize=14, **csfont)
plt.yticks(fontsize=14, **csfont)
plt.show

# Regression coefficient & p-value
print(f"The regression value is {round(rvalue,2)}.")
print(f"The r-squared is: {rvalue**2}.")
print(f"The p-value for this relationship is {round(pvalue,2)}.")
# Out:
# The regression value is 0.74.
# The r-squared is: 0.5458567737155111.
# The p-value for this relationship is 0.0.

# %% [markdown]
# ## Description
# There is a statistically significant positive relationship between latitude and maximum temperature for cities in the southern hemisphere, p < .001. As geographic location becomes closer to the equator (starting from the south), temperature increases. This relationship is strong, as latitude acccounts for over 54% of the variance in temperature.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set x and y values
x_values = northern_df['Latitude']
y_values = northern_df['Humidity']
                                                               
# Linear regression
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker='D', color='fuchsia', s=25, edgecolor='black')
plt.plot(x_values,regress_values,"cyan")
plt.xlabel('Latitude')
plt.ylabel('Humidiy (%))')

# Font formatting
csfont = {'fontname': "Georgia"}

# Set the title and axis labels
plt.title("Humidity by Latitude (Northern Hem.)", fontsize=15, fontweight='bold', **csfont)
plt.xlabel('Latitude', fontsize=14, fontweight='bold', **csfont)
plt.ylabel('Humidity (%)', fontsize=14, fontweight='bold', **csfont)
plt.xticks(fontsize=14, **csfont)
plt.yticks(fontsize=14, **csfont)
plt.ylim(0, 110)
plt.show

# Regression coefficient & p-value
print(f"The regression value is {round(rvalue,2)}.")
print(f"The r-squared is: {rvalue**2}.")
print(f"The p-value for this relationship is {round(pvalue,2)}.")
# Out:
# The regression value is 0.29.
# The r-squared is: 0.08171366263146788.
# The p-value for this relationship is 0.0.

# %% [markdown]
# ## Description
# There is a statistically significant positive relationship between latitude and humidity for cities in the northern hemisphere, p < .001. As geographic location moves further to the north (starting from the equator), humidity increases. This relationship is weak, as latitude accounts for only 8.1 percent of the varianxe in humidity.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set x and y values
x_values = southern_df['Latitude']
y_values = southern_df['Humidity']
                                                               
# Linear regression
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker='D', color='cyan', s=25, edgecolor='black')
plt.plot(x_values,regress_values,"fuchsia")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# Font formatting
csfont = {'fontname': "Georgia"}

# Set the title and axis labels
plt.title("Humidity by Latitude (Southern Hem.)", fontsize=15, fontweight='bold', **csfont)
plt.xlabel('Latitude', fontsize=14, fontweight='bold', **csfont)
plt.ylabel('Humidity (%)', fontsize=14, fontweight='bold', **csfont)
plt.xticks(fontsize=14, **csfont)
plt.yticks(fontsize=14, **csfont)
plt.ylim(0, 110)
plt.show

# Regression coefficient & p-value
print(f"The regression value is {round(rvalue,2)}.")
print(f"The r-squared is: {rvalue**2}.")
print(f"The p-value for this relationship is {round(pvalue,2)}.")
# Out:
# The regression value is -0.08.
# The r-squared is: 0.0061535719727773466.
# The p-value for this relationship is 0.31.

# %% [markdown]
# ## Description
# There is no statistical relationship between latitude and humidity for cities in the southern hemisphere, p > .05.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set x and y values
x_values = northern_df['Latitude']
y_values = northern_df['Cloudiness']
                                                               
# Linear regression
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker='D', color='fuchsia', s=25, edgecolor='black')
plt.plot(x_values,regress_values,"cyan")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%))')

# Font formatting
csfont = {'fontname': "Georgia"}

# Set the title and axis labels
plt.title("Cloudiness by Latitude (Northern Hem.)", fontsize=15, fontweight='bold', **csfont)
plt.xlabel('Latitude', fontsize=14, fontweight='bold', **csfont)
plt.ylabel('Cloudiness (%)', fontsize=14, fontweight='bold', **csfont)
plt.xticks(fontsize=14, **csfont)
plt.yticks(fontsize=14, **csfont)
plt.ylim(-10, 110)
plt.show

# Regression coefficient & p-value
print(f"The regression value is {round(rvalue,2)}.")
print(f"The r-squared is: {rvalue**2}.")
print(f"The p-value for this relationship is {round(pvalue,2)}.")
# Out:
# The regression value is 0.22.
# The r-squared is: 0.04954710746849747.
# The p-value for this relationship is 0.0.

# %% [markdown]
# ## Description
# There is a statistically significant positive relationship between latitude and cloudiness for cities in the northern hemisphere, p < .001. As geographic location moves further to the north (starting from the equator), cloudiness increases. This relationship is weak, as latitude accounts for only 4.9% of the variance in cloudiness.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set x and y values
x_values = southern_df['Latitude']
y_values = southern_df['Cloudiness']
                                                               
# Linear regression
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker='D', color='cyan', s=25, edgecolor='black')
plt.plot(x_values,regress_values,"fuchsia")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# Font formatting
csfont = {'fontname': "Georgia"}

# Set the title and axis labels
plt.title("Cloudiness by Latitude (Southern Hem.)", fontsize=15, fontweight='bold', **csfont)
plt.xlabel('Latitude', fontsize=14, fontweight='bold', **csfont)
plt.ylabel('Cloudiness (%)', fontsize=14, fontweight='bold', **csfont)
plt.xticks(fontsize=14, **csfont)
plt.yticks(fontsize=14, **csfont)
plt.ylim(-10, 110)
plt.show

# Regression coefficient & p-value
print(f"The regression value is {round(rvalue,2)}.")
print(f"The r-squared is: {rvalue**2}.")
print(f"The p-value for this relationship is {round(pvalue,2)}.")
# Out:
# The regression value is 0.16.
# The r-squared is: 0.025706951225698518.
# The p-value for this relationship is 0.04.

# %% [markdown]
# ## Description
# There is a statistically significant positive relationship between latitude and cloudiness for cities in the southern hemisphere, p < .05. As geographic location becomes closer to the equator (starting from the south), cloudiness increases. This relationship is weak, as latitude only accounts for approximately 2.5% of the variance in cloudiness.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set x and y values
x_values = northern_df['Latitude']
y_values = northern_df['Wind Speed']

# Linear regression
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker='D', color='fuchsia', s=25, edgecolor='black')
plt.plot(x_values,regress_values,"cyan")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph))')

# Font formatting
csfont = {'fontname': "Georgia"}

# Set the title and axis labels
plt.title("Wind Speed by Latitude (Northern Hem.)", fontsize=15, fontweight='bold', **csfont)
plt.xlabel('Latitude', fontsize=14, fontweight='bold', **csfont)
plt.ylabel('Wind Speed (mph)', fontsize=14, fontweight='bold', **csfont)
plt.xticks(fontsize=14, **csfont)
plt.yticks(fontsize=14, **csfont)
plt.ylim(-5, 35)
plt.show

# Regression coefficient & p-value
print(f"The regression value is {round(rvalue,2)}.")
print(f"The r-squared is: {rvalue**2}.")
print(f"The p-value for this relationship is {round(pvalue,2)}.")
# Out:
# The regression value is 0.03.
# The r-squared is: 0.0007246641926221261.
# The p-value for this relationship is 0.59.

# %% [markdown]
# ## Description
# There is no statistically significant relationship between latitude and wind speed for cities in the northern hemisphere, p > .05.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set x and y values
x_values = southern_df['Latitude']
y_values = southern_df['Wind Speed']
                                                               
# Linear regression
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker='D', color='cyan', s=25, edgecolor='black')
plt.plot(x_values,regress_values,"fuchsia")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

# Font formatting
csfont = {'fontname': "Georgia"}

# Set the title and axis labels
plt.title("Wind Speed by Latitude (Southern Hem.)", fontsize=15, fontweight='bold', **csfont)
plt.xlabel('Latitude', fontsize=14, fontweight='bold', **csfont)
plt.ylabel('Wind Speed (mph)', fontsize=14, fontweight='bold', **csfont)
plt.xticks(fontsize=14, **csfont)
plt.yticks(fontsize=14, **csfont)
plt.ylim(-5, 30)
plt.show

# Regression coefficient & p-value
print(f"The regression value is {round(rvalue,2)}.")
print(f"The r-squared is: {rvalue**2}.")
print(f"The p-value for this relationship is {round(pvalue,2)}.")
# Out:
# The regression value is -0.07.
# The r-squared is: 0.005518086515114942.
# The p-value for this relationship is 0.33.

# %% [markdown]
# ## Description
# There is no statistically significant relationship between latitude and wind speed for cities in the southern hemisphere, p > .05.
